# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanni-ollari/esercitazioni/blob/main/tips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/fav/tips.csv'

# %%
df= pd.read_csv(path)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#plt.figure(figsize=(10, 4))
sns.countplot(x='smoker',data=df);

# %%
#plt.figure(figsize=(10, 4))
sns.countplot(x='sex',data=df)

# %%
#plt.figure(figsize=(10, 4))
sns.countplot(x='day',data=df)

# %%
#plt.figure(figsize=(10, 4))
sns.countplot(x='time',data=df)

# %%
#plt.figure(figsize=(10, 4))
sns.countplot(y='time',data=df)

# %%
sns.pairplot(df, corner=True);

# %%
sns.pairplot(df, hue='sex')

# %%
sns.pairplot(df, hue='smoker')

# %%
sns.pairplot(df, hue='day')

# %%
sns.pairplot(df, hue='time')

# %%
sns.pairplot(df, hue='size')

# %%
sns.relplot(
    data=df, x="total_bill", y="tip",
    row="sex", col="time", hue="day",
    kind="scatter"
)

# %%
sns.relplot(x="total_bill", y="tip", col="time", hue="smoker", size="size", data=df);
