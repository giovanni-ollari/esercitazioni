# %%
def sommaduenum(x,y):
    ''' somma delle variabili x,y '''
    ris = x+y
    return ris

# %%
somma = sommaduenum(-150,100)
somma
# Out:
# -50

# %%
x = float(input('inserire un numero'))

if x<0:
  print('il num è neg')
elif x==0:
  print('il numero è zero, cambiare numero')
else:
  print('il num è pos')
# Out:
# inserire un numero3
# il num è pos

# %%
def pari_dispari(x):

    resto=x%2
    if resto==0:
      return 'il numero è pari'
    else:
      return 'il numero è dispari'

# %%
# %%writefile formulario.py

def area_triangolo(b,h):
    A = b*h/2
    return A
# Out:
# Writing formulario.py

# %%
b= int(input('inserisci un numero: '))
h= int(input('inserisci un numero: '))
print(area_triangolo(b,h))
# Out:
# inserisci un numero: 2
# inserisci un numero: 3
# 3.0

# %%
from formulario import area_triangolo as at

# %%
at(4,7)
# Out:
# 14.0

# %%
# %%writefile formulario.py

def perimetrotriangolo(x,y,z):
    p= x+y+z
    return p
# Out:
# Overwriting formulario.py

# %%
from formulario import perimetrotriangolo as pollo

# %%
pollo(3,4,5)
# Out:
# 12
